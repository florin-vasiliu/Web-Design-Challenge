# %%
import pandas as pd

# %%
dataset=pd.read_csv("Resources/analysis_data.csv")

# %%
dataset=dataset.set_index("City")
dataset
# Out:
#              Country Code  Lat [deg]  Long [deg]  Temperature [F]  \
# City
# rikitea                pf     -23.12     -134.97           77.036
# busselton              au     -33.65      115.33           81.428
# punta arenas           cl     -53.15      -70.92           50.000
# ushuaia                ar     -54.80      -68.30           53.600
# hobart                 au     -42.88      147.33           59.486
# ...                   ...        ...         ...              ...
# dikson                 ru      73.51       80.55           30.056
# college                us      64.86     -147.80           12.758
# havoysund              no      71.00       24.66           15.800
# narsaq                 gl      60.92      -46.05           19.400
# vardo                  no      70.37       31.11           20.156
#
#               Humidity [%]  Cloudiness [%]  Wind Speed [mph]
# City
# rikitea                 76              19              4.69
# ...

# %%
html_str=dataset.to_html()

# %%
Html_file= open("Resources/HTML_Table","w")
Html_file.write(html_str)
Html_file.close()
